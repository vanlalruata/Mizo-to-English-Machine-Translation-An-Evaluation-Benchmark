# %% [markdown]
# ## Mizo to English Textual Translation using Neural Machine Translation
#
# Smaller dataset of 2216 which is split into 75% train and 25% test set.

# %% [markdown]
# ### 1. Import the required packages

# %%
import string
import re
import tensorflow as tf
from numpy import array, argmax
from numpy.random import rand
from numpy.random import shuffle
from keras import layers
from keras.models import Model, load_model
from keras.layers import Input, Dense, LSTM, Bidirectional
from keras.layers import Embedding, RepeatVector, TimeDistributed, BatchNormalization
from keras_preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from tensorflow import keras
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from pickle import dump, load
from unicodedata import normalize
from nltk.translate.bleu_score import corpus_bleu
from sacrebleu.metrics import BLEU
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Important functions

# %%
def save_tokenizer(tokenizer, filename):
    dump(tokenizer, open(filename, 'wb'))
    print('Saved tokenizer: %s' % filename)
    
def load_doc(filename):
  # open the file as read only
  file = open(filename, mode='rt', encoding='utf-8')
  # read all text
  text = file.read()
  #close the file
  file.close()
  return text

def to_pairs(doc):
  lines = doc.strip().split('\n')
  pairs = [line.split('\t') for line in lines]
  return pairs

def clean_pairs(lines):
  cleaned = list()
  # Prepare regex for char filtering
  re_print = re.compile('[^%s]' % re.escape(string.printable))
  # Prepare translation table for removing punctuation
  table = str.maketrans('', '', string.punctuation)
  for pair in lines:
    clean_pair = list()
    for line in pair:
      # Normalize unicode characters
      line = normalize('NFD', line).encode('ascii', 'ignore')
      line = line.decode('UTF-8')
      # Tokenize on white space
      line = line.split()
      # Convert to lowercase
      line = [word.lower() for word in line]
      # Remove punctuation from each token
      line = [word.translate(table) for word in line]
      # Remove non-printable characters from each token
      line = [re_print.sub('', w) for w in line]
      # Remove tokens with numbers in them
      # line = [word for word in line if word.isalpha()]
      # Store as string
      clean_pair.append(' '.join(line))
    cleaned.append(clean_pair)
  return array(cleaned)

def load_clean_sentences(filename):
  return load(open(filename, 'rb'))

def save_clean_data(sentences, filename):
  dump(sentences, open(filename, 'wb'))
  print('Saved: %s' % filename)
    
def create_tokenizer(lines):
  tokenizer = Tokenizer()
  tokenizer.fit_on_texts(lines)
  return tokenizer

def max_length(lines):
  return max(len(line.split()) for line in lines)

def encode_sequences(tokenizer, length, lines):
  # Integer encode sequences
  X = tokenizer.texts_to_sequences(lines)
  # Pad sequences with 0 values
  X = pad_sequences(X, maxlen=length, padding='post')
  return X

def encode_output(sequences, vocab_size):
  ylist = list()
  for sequence in sequences:
    encoded = to_categorical(sequence, num_classes = vocab_size)
    ylist.append(encoded)
  y = array(ylist)
  y = y.reshape(sequences.shape[0], sequences.shape[1], vocab_size)
  return y

# %% [markdown]
# ### 3. Loading data and splitting

# %%
# Load dataset
filename = 'English-Mizo.txt'
doc = load_doc(filename)

# Split into Mizo - English pairs
pairs = to_pairs(doc)

# Clean sentences
clean_pairs = clean_pairs(pairs)

# Save clean pairs to file
# save_clean_data(clean_pairs, 'cleandata.pkl')

# Number of samples
n_sentences = 2200

dataset = clean_pairs

# Load dataset
# dataset = load_clean_sentences('cleandata.pkl')

#Limit the dataset
dataset = dataset[:n_sentences,:]
print("Length of dataset", len(dataset))

# Random Shuffle
shuffle(dataset)

# Split into train and test set
train, test = dataset[:1650], dataset[1650:]

print("Length of train", len(train))
print("Length of test", len(test))
# Out:
# Length of dataset 2200
# Length of train 1650
# Length of test 550

# %% [markdown]
# #### 3.1 Prepare Mizo  and English Tokenizer

# %%
miz_tokenizer = create_tokenizer(dataset[:,0])
miz_vocab_size = len(miz_tokenizer.word_index) + 1
miz_length = max_length(dataset[:,0])
print("MIZO")
print("Mizo Vocabulary Size: %d" % miz_vocab_size)
print("Mizo longest sentence: %d" % (miz_length))
print("Sample Mizo sentences\n",dataset[:,0])

eng_tokenizer = create_tokenizer(dataset[:,1])
eng_vocab_size = len(eng_tokenizer.word_index) + 1
eng_length = max_length(dataset[:, 1])
print("\n\nENGLISH")
print("English Vocabulary Size: %d" % eng_vocab_size)
print("English longest sentence: %d" % (eng_length))
print("Sample English sentences\n",dataset[:,1])

# Save tokenizers
save_tokenizer(miz_tokenizer, 'mizo_tokenizer.pkl')
print("Mizo Tokenizer Saved")
save_tokenizer(eng_tokenizer, 'eng_tokenizer.pkl')
print("English Tokenizer Saved")
# Out:
# MIZO
# Mizo Vocabulary Size: 1646
# Mizo longest sentence: 49
# Sample Mizo sentences
#  ['kan inbia chu ka lawm hle mai' 'i number min hrilh thei angem' 'umei'
#  ... 'hla hla i lo sa ang u' 'kaihza tha' 'mawngkua']
#
#
# ENGLISH
# English Vocabulary Size: 1618
# English longest sentence: 43
# Sample English sentences
#  ['nice talking with you' 'can you tell me your number' 'squash' ...
#  'lets sing a song' 'hough' 'anus']
# Saved tokenizer: mizo_tokenizer.pkl
# Mizo Tokenizer Saved
# Saved tokenizer: eng_tokenizer.pkl
# English Tokenizer Saved

# %%
plt.figure(figsize = (10,10))

sns.histplot([len(x) for x in dataset[:,0]], color='purple', kde=True, label='English')
sns.histplot([len(x) for x in dataset[:,1]], color='green', kde=True, label='Mizo')
plt.title('Distribution of Sentences Length')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,10))
sns.displot([len(x) for x in dataset[:,0]], label='English')
#sns.displot([len(x) for x in dataset[:,1]], label='Mizo')

plt.title('Distribution of Sentences Length')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (15,15))
#sns.distplot([len(x) for x in dataset[:,0]], label='English')
sns.displot([len(x) for x in dataset[:,1]], label='Mizo')

plt.title('Distribution of Sentences Length')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,8))
sns.histplot([len(x) for x in dataset[:,0]], label='English')
sns.histplot([len(x) for x in dataset[:,1]], label='Mizo')

plt.title('Distribution of Sentences Length')
plt.legend()
plt.show()

# %% [markdown]
# #### 3.2 Prepare training data

# %%
trainX = encode_sequences(miz_tokenizer, miz_length, train[:, 0])
trainY = encode_sequences(eng_tokenizer, eng_length, train[:, 1])
trainY = encode_output(trainY, eng_vocab_size)

# %% [markdown]
# #### 3.3 Prepare validation and test data

# %%
testX = encode_sequences(miz_tokenizer, miz_length, test[:, 0])
testY = encode_sequences(eng_tokenizer, eng_length, test[:, 1])
testY = encode_output(testY, eng_vocab_size)

# %% [markdown]
# ### 4. Define and call the model and display summary - BiLSTM

# %%
def define_model(src_vocab, tar_vocab, src_timesteps, tar_timesteps, n_units):
  model = keras.Sequential()
  model.add(Embedding(src_vocab, n_units, input_length=src_timesteps, mask_zero=True))
  model.add(BatchNormalization())
  model.add(Bidirectional(LSTM(n_units)))
  model.add(BatchNormalization())
  model.add(RepeatVector(tar_timesteps))
  model.add(Bidirectional(LSTM(n_units, return_sequences=True)))
  model.add(BatchNormalization())
  model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))
  return model


opt = tf.keras.optimizers.Adam(learning_rate=0.001)

# Call the define model function
model = define_model(miz_vocab_size, eng_vocab_size, miz_length, eng_length, 256)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Summarize the defined model
print(model.summary())

#plot model
plot_model(model, to_file='model.eps', show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 49, 256)           421376
#
#  batch_normalization_3 (Batc  (None, 49, 256)          1024
#  hNormalization)
#
#  bidirectional_2 (Bidirectio  (None, 512)              1050624
#  nal)
#
#  batch_normalization_4 (Batc  (None, 512)              2048
#  hNormalization)
#
#  repeat_vector_1 (RepeatVect  (None, 43, 512)          0
#  or)
#
#  bidirectional_3 (Bidirectio  (None, 43, 512)          1574912
#  nal)
#
#  batch_normalization_5 (Batc  (None, 43, 512)          2048
#  hNormalization)
#
#  time_distributed_1 (TimeDis  (None, 43, 1618)         830034
#  tributed)
#
# =================================================================
# Total params: 3,882,066
# Trainable params: 3,879,506
# Non-trainable params: 2,560
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ### 5. Fit and train the model

# %%
filename = 'mizen_using_bilstm_model.h5'
checkpoint = ModelCheckpoint(filename, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
history = model.fit(trainX, trainY, epochs=30, batch_size=32, validation_data=(testX, testY), callbacks=[checkpoint])
# Out:
# Epoch 1/30
# 52/52 [==============================] - ETA: 0s - loss: 4.9662 - accuracy: 0.6189
# Epoch 1: val_loss improved from inf to 2.86586, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 15s 97ms/step - loss: 4.9662 - accuracy: 0.6189 - val_loss: 2.8659 - val_accuracy: 0.9177
# Epoch 2/30
# 50/52 [===========================>..] - ETA: 0s - loss: 2.5968 - accuracy: 0.8054
# Epoch 2: val_loss improved from 2.86586 to 0.98417, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 2s 30ms/step - loss: 2.5894 - accuracy: 0.8054 - val_loss: 0.9842 - val_accuracy: 0.9088
# Epoch 3/30
# 50/52 [===========================>..] - ETA: 0s - loss: 1.5814 - accuracy: 0.8647
# Epoch 3: val_loss improved from 0.98417 to 0.86045, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 2s 29ms/step - loss: 1.5832 - accuracy: 0.8645 - val_loss: 0.8605 - val_accuracy: 0.9168
# Epoch 4/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.8950 - accuracy: 0.9010
# Epoch 4: val_loss improved from 0.86045 to 0.79178, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 2s 30ms/step - loss: 0.8866 - accuracy: 0.9014 - val_loss: 0.7918 - val_accuracy: 0.9222
# Epoch 5/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.6822 - accuracy: 0.9119
# Epoch 5: val_loss improved from 0.79178 to 0.72045, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 2s 30ms/step - loss: 0.6772 - accuracy: 0.9123 - val_loss: 0.7204 - val_accuracy: 0.9230
# Epoch 6/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.5999 - accuracy: 0.9156
# Epoch 6: val_loss improved from 0.72045 to 0.60249, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 2s 29ms/step - loss: 0.5977 - accuracy: 0.9157 - val_loss: 0.6025 - val_accuracy: 0.9241
# Epoch 7/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.4822 - accuracy: 0.9231
# Epoch 7: val_loss improved from 0.60249 to 0.55723, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 2s 29ms/step - loss: 0.4799 - accuracy: 0.9235 - val_loss: 0.5572 - val_accuracy: 0.9244
# Epoch 8/30
# 52/52 [==============================] - ETA: 0s - loss: 0.4241 - accuracy: 0.9270
# Epoch 8: val_loss improved from 0.55723 to 0.53963, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 2s 30ms/step - loss: 0.4241 - accuracy: 0.9270 - val_loss: 0.5396 - val_accuracy: 0.9246
# Epoch 9/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.3873 - accuracy: 0.9300
# Epoch 9: val_loss did not improve from 0.53963
# 52/52 [==============================] - 1s 28ms/step - loss: 0.3883 - accuracy: 0.9298 - val_loss: 0.6703 - val_accuracy: 0.9121
# Epoch 10/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.3549 - accuracy: 0.9324
# Epoch 10: val_loss did not improve from 0.53963
# 52/52 [==============================] - 1s 28ms/step - loss: 0.3548 - accuracy: 0.9325 - val_loss: 0.5495 - val_accuracy: 0.9239
# Epoch 11/30
# 52/52 [==============================] - ETA: 0s - loss: 0.3191 - accuracy: 0.9351
# Epoch 11: val_loss improved from 0.53963 to 0.51479, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 1s 29ms/step - loss: 0.3191 - accuracy: 0.9351 - val_loss: 0.5148 - val_accuracy: 0.9277
# Epoch 12/30
# 52/52 [==============================] - ETA: 0s - loss: 0.2908 - accuracy: 0.9387
# Epoch 12: val_loss improved from 0.51479 to 0.49624, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 1s 28ms/step - loss: 0.2908 - accuracy: 0.9387 - val_loss: 0.4962 - val_accuracy: 0.9310
# Epoch 13/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.2608 - accuracy: 0.9420
# Epoch 13: val_loss did not improve from 0.49624
# 52/52 [==============================] - 1s 28ms/step - loss: 0.2612 - accuracy: 0.9419 - val_loss: 0.5105 - val_accuracy: 0.9283
# Epoch 14/30
# 52/52 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.9458
# Epoch 14: val_loss did not improve from 0.49624
# 52/52 [==============================] - 1s 27ms/step - loss: 0.2339 - accuracy: 0.9458 - val_loss: 0.5359 - val_accuracy: 0.9271
# Epoch 15/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.2220 - accuracy: 0.9484
# Epoch 15: val_loss improved from 0.49624 to 0.48972, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 1s 28ms/step - loss: 0.2218 - accuracy: 0.9484 - val_loss: 0.4897 - val_accuracy: 0.9330
# Epoch 16/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.1954 - accuracy: 0.9515
# Epoch 16: val_loss improved from 0.48972 to 0.48886, saving model to mizen_using_bilstm_model.h5
# 52/52 [==============================] - 1s 29ms/step - loss: 0.1958 - accuracy: 0.9513 - val_loss: 0.4889 - val_accuracy: 0.9350
# Epoch 17/30
# 52/52 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9532
# Epoch 17: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.1879 - accuracy: 0.9532 - val_loss: 0.5197 - val_accuracy: 0.9306
# Epoch 18/30
# 52/52 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9538
# Epoch 18: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.1786 - accuracy: 0.9538 - val_loss: 0.5147 - val_accuracy: 0.9320
# Epoch 19/30
# 52/52 [==============================] - ETA: 0s - loss: 0.1533 - accuracy: 0.9594
# Epoch 19: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.1533 - accuracy: 0.9594 - val_loss: 0.5018 - val_accuracy: 0.9358
# Epoch 20/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1339 - accuracy: 0.9635
# Epoch 20: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.1331 - accuracy: 0.9637 - val_loss: 0.5212 - val_accuracy: 0.9342
# Epoch 21/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.1256 - accuracy: 0.9645
# Epoch 21: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 28ms/step - loss: 0.1253 - accuracy: 0.9646 - val_loss: 0.5248 - val_accuracy: 0.9351
# Epoch 22/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1255 - accuracy: 0.9642
# Epoch 22: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.1244 - accuracy: 0.9645 - val_loss: 0.5260 - val_accuracy: 0.9345
# Epoch 23/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.1172 - accuracy: 0.9664
# Epoch 23: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.1170 - accuracy: 0.9664 - val_loss: 0.5333 - val_accuracy: 0.9362
# Epoch 24/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.1057 - accuracy: 0.9684
# Epoch 24: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 28ms/step - loss: 0.1050 - accuracy: 0.9686 - val_loss: 0.5333 - val_accuracy: 0.9347
# Epoch 25/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0988 - accuracy: 0.9704
# Epoch 25: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.0991 - accuracy: 0.9704 - val_loss: 0.5446 - val_accuracy: 0.9354
# Epoch 26/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.1011 - accuracy: 0.9702
# Epoch 26: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.1011 - accuracy: 0.9701 - val_loss: 0.6132 - val_accuracy: 0.9258
# Epoch 27/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.0955 - accuracy: 0.9716
# Epoch 27: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.0957 - accuracy: 0.9715 - val_loss: 0.5436 - val_accuracy: 0.9365
# Epoch 28/30
# 51/52 [============================>.] - ETA: 0s - loss: 0.0885 - accuracy: 0.9740
# Epoch 28: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.0891 - accuracy: 0.9738 - val_loss: 0.5410 - val_accuracy: 0.9364
# Epoch 29/30
# 52/52 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9748
# Epoch 29: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.0839 - accuracy: 0.9748 - val_loss: 0.5443 - val_accuracy: 0.9369
# Epoch 30/30
# 50/52 [===========================>..] - ETA: 0s - loss: 0.0783 - accuracy: 0.9760
# Epoch 30: val_loss did not improve from 0.48886
# 52/52 [==============================] - 1s 27ms/step - loss: 0.0781 - accuracy: 0.9760 - val_loss: 0.5458 - val_accuracy: 0.9372

# %% [markdown]
# ### 6. Evaluate the Neural Machine Translation Model

# %%
# map an integer to a word
def word_for_id(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# generate target given source sequence
def predict_sequence(model, tokenizer, source):
    prediction = model.predict(source, verbose=0)[0]
    integers = [argmax(vector) for vector in prediction]
    target = list()
    for i in integers:
        word = word_for_id(i, tokenizer)
        if word is None:
            break
        target.append(word)
    return ' '.join(target)

# evaluate the skill of the model
def evaluate_model(model, tokenizer, sources, raw_dataset):
    actual, predicted = list(), list()
    for i, source in enumerate(sources):
        # translate encoded source text
        source = source.reshape((1, source.shape[0]))
        translation = predict_sequence(model, eng_tokenizer, source)
        raw_src, raw_target = raw_dataset[i]
        if i < 10:
            print('src=[%s], target=[%s], predicted=[%s]' % (raw_src, raw_target, translation))
        actual.append([raw_target.split()])
        predicted.append(translation.split())
    
    # calculate BLEU score
    print('BLEU-1: %f' % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
    print('BLEU-2: %f' % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
    print('BLEU-3: %f' % corpus_bleu(actual, predicted, weights=(0.3, 0.3, 0.3, 0)))
    print('BLEU-4: %f' % corpus_bleu(actual, predicted, weights=(0.25, 0.25, 0.25, 0.25)))
    print('Final BLEU score: %f' % corpus_bleu(actual, predicted))
    
# Load model
model = load_model('mizen_using_bilstm_model.h5')

# Evaluate the model
print("\nUSING TRAINING DATA")
evaluate_model(model, miz_tokenizer, trainX, train)

# Test on some test sequences
print("\nUSING TEST DATA")
evaluate_model(model, miz_tokenizer, testX, test)
# Out:
# USING TRAINING DATA
# src=[kan inbia chu ka lawm hle mai], target=[nice talking with you], predicted=[nice talking talking you]
# src=[i number min hrilh thei angem], target=[can you tell me your number], predicted=[can you tell me]
# src=[umei], target=[squash], predicted=[gourd]
# src=[i tawngkam tha avangin ka lawm e], target=[thank for your kind words], predicted=[thank for kind]
# src=[chawngkawr], target=[cobra], predicted=[cobra]
# src=[a dik khawiah pawh cheng ila ka in siamrem ve thei mai zel], target=[right i can adapt myself wherever i live in], predicted=[i i i adapt myself wherever wherever]
# src=[keite], target=[panther], predicted=[panther]
# src=[kutzungtang], target=[finger], predicted=[finger]
# src=[kekawn], target=[arch of the foot], predicted=[of of of of of of of]
# src=[rulngan], target=[king cobra], predicted=[king cobra]
# BLEU-1: 0.584767
# BLEU-2: 0.402985
# BLEU-3: 0.312246
# BLEU-4: 0.181577
# Final BLEU score: 0.181577
#
# USING TEST DATA
# src=[bazar ah ka kal duh], target=[i want to go market], predicted=[i want to go hotel]
# src=[ka lung a leng], target=[i am feeling lonely], predicted=[i am feeling]
# src=[keite], target=[leopard], predicted=[panther]
# src=[internet ah online in saptawng atanga mizo tawng a tawng lehlin i ti thei em], target=[can you do online translation from english to mizo language in internet], predicted=[do do do language language language language language]
# src=[thinlung takin ka lawmpui che], target=[hearty congratulation], predicted=[i a good]
# src=[biak inah hla kan sa], target=[we sing a song in the church], predicted=[church church church church church]
# src=[a hlui zawk ka duh], target=[i like older], predicted=[i want want number]
# src=[min rawn tlawh a a lawmawm hle mai], target=[thanks for your visit], predicted=[you been so words]
# src=[instagram i hmang em], target=[are you using instagram], predicted=[do you you]
# src=[google in mizo tawng lehlinna an dah tawh], target=[google has added mizo language translate], predicted=[church you to to in]
# BLEU-1: 0.261957
# BLEU-2: 0.155090
# BLEU-3: 0.105386
# BLEU-4: 0.042782
# Final BLEU score: 0.042782

# %% [markdown]
# ### 7. Plot different graphs of the model

# %%
# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sn

# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Loss vs Epoch on train and test data")
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper right')
#plt.savefig('plots/ae_binary_loss.png')
plt.show()

# %%
# Plot of loss vs epoch of train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Accuracy vs Epoch on train and test data")
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='lower right')
#plt.savefig('plots/ae_binary_loss.png')
plt.show()

# %%
import pandas as pd

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(-0.02,1.02)
plt.title('Scores on different epochs.')
plt.xlabel('Epochs')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# # Important function to process input and translate sentence

# %%
#working to translate on hand
def preprocess_input(sentence, tokenizer, max_length):
    sentence = normalize('NFD', sentence).encode('ascii', 'ignore')
    sentence = sentence.decode('UTF-8')
    sentence = sentence.split()
    sentence = [word.lower() for word in sentence]
    sentence = [word.translate(str.maketrans('', '', string.punctuation)) for word in sentence]
    sentence = [re.sub('[^a-zA-Z]', '', word) for word in sentence]
    sentence = ' '.join(sentence)
    sentence = [sentence]
    sentence = tokenizer.texts_to_sequences(sentence)
    sentence = pad_sequences(sentence, maxlen=max_length, padding='post')
    return sentence

# Function to translate the input sentence
def translate_sentence(model, mizo_tokenizer, eng_tokenizer, sentence):
    max_length_mizo = model.input_shape[1]
    sentence = preprocess_input(sentence, mizo_tokenizer, max_length_mizo)
    translation = model.predict(sentence, verbose=0)[0]
    integers = [argmax(vector) for vector in translation]
    target = []
    for i in integers:
        word = word_for_id(i, eng_tokenizer)
        if word is None:
            break
        target.append(word)
    return ' '.join(target)

# %%
# Load the saved model
model = load_model('mizen_using_bilstm_model.h5')

# Function to load the Mizo tokenizer
def load_mizo_tokenizer():
    return load(open('mizo_tokenizer.pkl', 'rb'))

# Function to load the English tokenizer
def load_eng_tokenizer():
    return load(open('eng_tokenizer.pkl', 'rb'))

# %%
# Load tokenizers
mizo_tokenizer = load_mizo_tokenizer()
eng_tokenizer = load_eng_tokenizer()

# %%
# Prompt user for a Mizo sentence
user_input = input("Enter a Mizo sentence: ")

# Translate the entered sentence
translation = translate_sentence(model, mizo_tokenizer, eng_tokenizer, user_input)

# Display the translation
print("English Translation:", translation)
# Out:
# Enter a Mizo sentence: internet ah online in saptawng atanga mizo tawng a tawng lehlin i ti thei em
# English Translation: do do do language language language language language
